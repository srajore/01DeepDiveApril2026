# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="openai/gpt-oss-120b",
    task="text-generation"
)

chat_model = ChatHuggingFace(llm=llm)

# %%
response = chat_model.invoke("Does GOD exist?")

# %%
print(response.content)
# Out:
# The question “Does God exist?” is one of the oldest and most debated topics in philosophy, theology, science, and everyday life. Because it touches on matters of metaphysics, personal experience, and cultural tradition, there is no single answer that is universally accepted. Below is a broad overview of the main lines of thought, the reasons people give for each position, and some ways you can explore the issue further.
#
# ---
#
# ## 1. What “God” Usually Means
#
# | Tradition | Typical Attributes |
# |-----------|--------------------|
# | **Classical theism (e.g., Christianity, Islam, Judaism)** | Omnipotent, omniscient, omnibenevolent, eternal, creator of the universe |
# | **Deism** | Creator who set the universe in motion but does not intervene |
# | **Pantheism / Panentheism** | God is identical with the universe (or contains it) |
# | **Polytheistic / Animistic** | Multiple divine beings or spirits associated with natural forces |
# | **Non‑theistic “God”** | Symbolic, moral ideal, or ultimate reality (e.g., some Buddhist or secular humanist uses) |
#
# The arguments you’ll encounter often presuppose one of these conceptions—usually the classical theistic one—but the conclusions can differ dramatically depending on the definition.
#
# ---
#
# ## 2. Arguments **for** the Existence of God
#
# | Category | Core Idea | Representative Proponents | Main Strengths |
# |----------|-----------|---------------------------|----------------|
# | **Cosmological** | Something must cause the existence of the universe; a necessary, uncaused cause is God. | Thomas Aquinas (Five Ways), William Lane Craig (Kalam argument) | Appeals to intuitive sense
